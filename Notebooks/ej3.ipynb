# %% [markdown]
# Ejercicio 3

# %% [markdown]
# Importación de funciones
#
# En esta celda importamos desde la carpeta `src` las funciones necesarias para resolver el ejercicio.
# Estas funciones permiten:
# obtener la lista de spoilers ingresados por el usuario,
# limpiar las palabras para compararlas correctamente,
# y reemplazar los spoilers por asteriscos en la reseña.

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.ejercicio3 import (
    obtener_spoilers,
    reemplazar_spoilers
)

# %% [markdown]
# Definición de la reseña
#
# En esta celda definimos el texto de la reseña de la película que vamos a procesar.

# %%
review = """La película sigue a un grupo de astronautas que
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo
a través
de tormentas solares y fallos en el sistema de navegación. Al
llegar
a Marte descubren que la base está abandonada y los
suministros
destruidos. Torres decide sacrificar la nave nodriza para
salvar
al equipo y logran volver a la Tierra en una cápsula de
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""

# %% [markdown]
# Ingreso de spoilers
#
# En esta celda pedimos al usuario las palabras que quiere considerar como spoilers.
# Luego, esas palabras se separan por coma y se procesan para compararlas más fácilmente.

# %%
entrada = input("Ingrese las palabras spoiler (separadas por coma): ")
spoilers = obtener_spoilers(entrada)

# %% [markdown]
# Procesamiento de la reseña
#
# En esta celda reemplazamos cada palabra spoiler encontrada en la reseña por una secuencia de asteriscos de la misma longitud.

# %%
texto_final = reemplazar_spoilers(review, spoilers)

# %% [markdown]
# Resultado obtenido
#
# En esta celda mostramos la reseña final con los spoilers ocultos.

# %%
print(texto_final)
# Out:
# La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate. El capitán ****** lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a ***** descubren que la base está abandonada y los suministros destruidos. ****** decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que ****** sobrevivió gracias a un pasaje secreto.
