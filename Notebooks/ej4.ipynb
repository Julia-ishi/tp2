# %% [markdown]
# Ejercicio 4

# %% [markdown]
# Importación de funciones
#
# En esta celda importamos desde la carpeta `src` las funciones necesarias para validar una dirección de email.
# Las funciones permiten verificar:
# si el email tiene exactamente un "@",
# si tiene texto antes del "@",
# si tiene un punto después del "@",
# si no empieza ni termina con caracteres inválidos,
# y si el dominio tiene al menos 2 caracteres.

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.ejercicio4 import validar_email

# %% [markdown]
# Ingreso del email
#
# En esta celda solicitamos al usuario que ingrese una dirección de email para validar.

# %%
email = input("Ingrese un email: ")

# %% [markdown]
# Validación del email
#
# En esta celda utilizamos la función `validar_email` para determinar si el email ingresado cumple con las condiciones establecidas.

# %%
es_valido = validar_email(email)

# %% [markdown]
# Resultado obtenido
#
# En esta celda mostramos si el email es válido o no según las reglas definidas.

# %%
if es_valido:
    print("El email es válido.")
else:
    print("El email no es válido.")
# Out:
# El email es válido.
