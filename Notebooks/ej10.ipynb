# %% [markdown]
# Ejercicio 10

# %% [markdown]
# Importacion de funciones
#
# En esta celda importamos desde la carpeta `src` las funciones necesarias para resolver el ejercicio.
#
# Estas funciones permiten:
# -obtener la lista de participantes,
# -crear las estadisticas iniciales,
# -procesar cada ronda de la competencia,
# -armar la tabla de posiciones,
# -e imprimir los resultados de forma clara.

# %%
import sys
import os
sys.path.append(os.path.abspath("..")) # Agrega el directorio padre al path para importar módulos
from src.ejercicio10 import mostrar_resultados_competencia

# %% [markdown]
# Definicion de las rondas
#
# En esta celda definimos la estructura de datos con todas las rondas de la competencia.
#
# Cada ronda tiene:
# -un tema
# -un diccionario con los puntajes de cada participante.
#
# Cada participante tiene ademas los puntajes dados por los tres jueces.

# %%
rounds = [
    {
        "theme": "Entrada",
        "scores": {
            "Valentina": {"judge_1": 8, "judge_2": 7, "judge_3": 9},
            "Mateo": {"judge_1": 7, "judge_2": 8, "judge_3": 7},
            "Camila": {"judge_1": 9, "judge_2": 9, "judge_3": 8},
            "Santiago": {"judge_1": 6, "judge_2": 7, "judge_3": 6},
            "Lucía": {"judge_1": 8, "judge_2": 8, "judge_3": 8}
        }
    },
    {
        "theme": "Plato principal",
        "scores": {
            "Valentina": {"judge_1": 9, "judge_2": 9, "judge_3": 8},
            "Mateo": {"judge_1": 8, "judge_2": 7, "judge_3": 9},
            "Camila": {"judge_1": 7, "judge_2": 6, "judge_3": 7},
            "Santiago": {"judge_1": 9, "judge_2": 8, "judge_3": 8},
            "Lucía": {"judge_1": 7, "judge_2": 8, "judge_3": 7}
        }
    },
    {
        "theme": "Postre",
        "scores": {
            "Valentina": {"judge_1": 7, "judge_2": 8, "judge_3": 7},
            "Mateo": {"judge_1": 9, "judge_2": 9, "judge_3": 8},
            "Camila": {"judge_1": 8, "judge_2": 7, "judge_3": 9},
            "Santiago": {"judge_1": 7, "judge_2": 7, "judge_3": 6},
            "Lucía": {"judge_1": 9, "judge_2": 9, "judge_3": 9}
        }
    },
    {
        "theme": "Cocina internacional",
        "scores": {
            "Valentina": {"judge_1": 8, "judge_2": 9, "judge_3": 9},
            "Mateo": {"judge_1": 7, "judge_2": 6, "judge_3": 7},
            "Camila": {"judge_1": 9, "judge_2": 8, "judge_3": 8},
            "Santiago": {"judge_1": 8, "judge_2": 9, "judge_3": 7},
            "Lucía": {"judge_1": 7, "judge_2": 7, "judge_3": 8}
        }
    },
    {
        "theme": "Final libre",
        "scores": {
            "Valentina": {"judge_1": 9, "judge_2": 8, "judge_3": 9},
            "Mateo": {"judge_1": 8, "judge_2": 9, "judge_3": 8},
            "Camila": {"judge_1": 7, "judge_2": 7, "judge_3": 7},
            "Santiago": {"judge_1": 9, "judge_2": 9, "judge_3": 9},
            "Lucía": {"judge_1": 8, "judge_2": 8, "judge_3": 7}
        }
    }
]

# %% [markdown]
# Ejecucion de la competencia
#
# En esta celda llamamos a la funcion principal del ejercicio.
#
# La funcion se encarga de:
# -recorrer cada ronda
# -calcular el ganador de la ronda
# -actualizar las estadisticas acumuladas
# -mostrar la tabla de posiciones luego de cada ronda
# -imprimir la tabla final ordenada por puntaje total

# %%
mostrar_resultados_competencia(rounds)
# Out:
# Ronda 1 - Entrada:
# Ganador: Camila (26 pts)
#
# Tabla de posiciones:
#
# Cocinero: Camila
#   Puntaje total: 26
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 26.0
# ------------------------------
# Cocinero: Valentina
#   Puntaje total: 24
#   Rondas ganadas: 0
#   Mejor ronda: 24
#   Promedio: 24.0
# ------------------------------
# Cocinero: Lucía
#   Puntaje total: 24
#   Rondas ganadas: 0
#   Mejor ronda: 24
#   Promedio: 24.0
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 22
#   Rondas ganadas: 0
#   Mejor ronda: 22
#   Promedio: 22.0
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 19
#   Rondas ganadas: 0
#   Mejor ronda: 19
#   Promedio: 19.0
# ------------------------------
#
# Ronda 2 - Plato principal:
# Ganador: Valentina (26 pts)
#
# Tabla de posiciones:
#
# Cocinero: Valentina
#   Puntaje total: 50
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 25.0
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 46
#   Rondas ganadas: 0
#   Mejor ronda: 24
#   Promedio: 23.0
# ------------------------------
# Cocinero: Camila
#   Puntaje total: 46
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 23.0
# ------------------------------
# Cocinero: Lucía
#   Puntaje total: 46
#   Rondas ganadas: 0
#   Mejor ronda: 24
#   Promedio: 23.0
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 44
#   Rondas ganadas: 0
#   Mejor ronda: 25
#   Promedio: 22.0
# ------------------------------
#
# Ronda 3 - Postre:
# Ganador: Lucía (27 pts)
#
# Tabla de posiciones:
#
# Cocinero: Lucía
#   Puntaje total: 73
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 24.3
# ------------------------------
# Cocinero: Valentina
#   Puntaje total: 72
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 24.0
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 72
#   Rondas ganadas: 0
#   Mejor ronda: 26
#   Promedio: 24.0
# ------------------------------
# Cocinero: Camila
#   Puntaje total: 70
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 23.3
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 64
#   Rondas ganadas: 0
#   Mejor ronda: 25
#   Promedio: 21.3
# ------------------------------
#
# Ronda 4 - Cocina internacional:
# Ganador: Valentina (26 pts)
#
# Tabla de posiciones:
#
# Cocinero: Valentina
#   Puntaje total: 98
#   Rondas ganadas: 2
#   Mejor ronda: 26
#   Promedio: 24.5
# ------------------------------
# Cocinero: Camila
#   Puntaje total: 95
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 23.8
# ------------------------------
# Cocinero: Lucía
#   Puntaje total: 95
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 23.8
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 92
#   Rondas ganadas: 0
#   Mejor ronda: 26
#   Promedio: 23.0
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 88
#   Rondas ganadas: 0
#   Mejor ronda: 25
#   Promedio: 22.0
# ------------------------------
#
# Ronda 5 - Final libre:
# Ganador: Santiago (27 pts)
#
# Tabla de posiciones:
#
# Cocinero: Valentina
#   Puntaje total: 124
#   Rondas ganadas: 2
#   Mejor ronda: 26
#   Promedio: 24.8
# ------------------------------
# Cocinero: Lucía
#   Puntaje total: 118
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 23.6
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 117
#   Rondas ganadas: 0
#   Mejor ronda: 26
#   Promedio: 23.4
# ------------------------------
# Cocinero: Camila
#   Puntaje total: 116
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 23.2
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 115
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 23.0
# ------------------------------
#
# Tabla de posiciones final:
#
# Cocinero: Valentina
#   Puntaje total: 124
#   Rondas ganadas: 2
#   Mejor ronda: 26
#   Promedio: 24.8
# ------------------------------
# Cocinero: Lucía
#   Puntaje total: 118
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 23.6
# ------------------------------
# Cocinero: Mateo
#   Puntaje total: 117
#   Rondas ganadas: 0
#   Mejor ronda: 26
#   Promedio: 23.4
# ------------------------------
# Cocinero: Camila
#   Puntaje total: 116
#   Rondas ganadas: 1
#   Mejor ronda: 26
#   Promedio: 23.2
# ------------------------------
# Cocinero: Santiago
#   Puntaje total: 115
#   Rondas ganadas: 1
#   Mejor ronda: 27
#   Promedio: 23.0
# ------------------------------
